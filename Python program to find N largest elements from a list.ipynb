# %% [markdown]
# # Python program to find N largest elements from a list

# %%
from IPython.display import Image
Image("//home//saket//Pictures//Screenshot from 2021-04-14 07-34-32.png")

# %%
def Nlargest(arr,n):
    arr.sort()
    print(arr)
    print("N largest number in the list:",arr[-n:])

# %%
arr = [4,5,7,89,11,22,44,55,-89,45]
n = 3
Nlargest(arr,n)
# Out:
# [-89, 4, 5, 7, 11, 22, 44, 45, 55, 89]
# N largest number in the list: [45, 55, 89]

# %%
def Nlargest(list1,n):
    final_list = []
    
    for i in range(0, N):
        max1 = 0  
        for j in range(len(list1)):
            if list1[j] > max1:
                max1 = list1[j];
                  
        list1.remove(max1);
        final_list.append(max1)
          
    print(final_list)

# %%
arr = [4,5,7,89,11,22,44,55,-89,45]
N = 3
Nlargest(arr,N)
# Out:
# [89, 55, 45]
